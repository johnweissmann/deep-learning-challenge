# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=["EIN","NAME"])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = application_df['APPLICATION_TYPE'].value_counts().loc[lambda x : x < 200].index

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df['CLASSIFICATION'].value_counts().loc[lambda x : x>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace =  application_df['CLASSIFICATION'].value_counts().loc[lambda x : x < 800].index

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
app_dummies = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
y = app_dummies['IS_SUCCESSFUL']
X = app_dummies.drop(columns = 'IS_SUCCESSFUL')

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()
# list = ['sigmoid','relu','tanh']

number_input_features = 43

# First hidden layer
nn.add(tf.keras.layers.Dense(units=10, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=45, activation="relu"))

# More layers
nn.add(tf.keras.layers.Dense(units=60, activation='relu'))
nn.add(tf.keras.layers.Dense(units=30, activation='relu'))
nn.add(tf.keras.layers.Dense(units=10, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation = 'sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_54 (Dense)            (None, 10)                440
#
#  dense_55 (Dense)            (None, 45)                495
#
#  dense_56 (Dense)            (None, 60)                2760
#
#  dense_57 (Dense)            (None, 30)                1830
#
#  dense_58 (Dense)            (None, 10)                310
#
#  dense_59 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 5846 (22.84 KB)
# Trainable params: 5846 (22.84 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 6s 4ms/step - loss: 0.7105 - accuracy: 0.6937
# Epoch 2/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6191 - accuracy: 0.7175
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5901 - accuracy: 0.7252
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6071 - accuracy: 0.7124
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5743 - accuracy: 0.7259
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5720 - accuracy: 0.7230
# Epoch 7/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5730 - accuracy: 0.7244
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5664 - accuracy: 0.7231
# Epoch 9/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5638 - accuracy: 0.7264
# Epoch 10/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5601 - accuracy: 0.7287
# Epoch 11/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5632 - accuracy: 0.7259
# Epoch 12/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5600 - accuracy: 0.7290
# Epoch 13/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5630 - accuracy: 0.7306
# Epoch 14/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5597 - accuracy: 0.7319
# Epoch 15/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5663 - accuracy: 0.7266
# Epoch 16/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5579 - accuracy: 0.7321
# Epoch 17/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5576 - accuracy: 0.7336
# Epoch 18/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5593 - accuracy: 0.7322
# Epoch 19/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5629 - accuracy: 0.7337
# Epoch 20/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5559 - accuracy: 0.7328
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5619 - accuracy: 0.7305
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5555 - accuracy: 0.7340
# Epoch 23/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5542 - accuracy: 0.7331
# Epoch 24/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5550 - accuracy: 0.7347
# Epoch 25/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5538 - accuracy: 0.7345
# Epoch 26/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5552 - accuracy: 0.7341
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5569 - accuracy: 0.7331
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5520 - accuracy: 0.7343
# Epoch 29/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5545 - accuracy: 0.7337
# Epoch 30/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5574 - accuracy: 0.7336
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5525 - accuracy: 0.7359
# Epoch 32/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5527 - accuracy: 0.7359
# Epoch 33/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5550 - accuracy: 0.7351
# Epoch 34/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5584 - accuracy: 0.7342
# Epoch 35/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5524 - accuracy: 0.7351
# Epoch 36/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5536 - accuracy: 0.7335
# Epoch 37/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5532 - accuracy: 0.7337
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5487 - accuracy: 0.7347
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5576 - accuracy: 0.7347
# Epoch 40/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5667 - accuracy: 0.7179
# Epoch 41/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5709 - accuracy: 0.7306
# Epoch 42/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5522 - accuracy: 0.7343
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5535 - accuracy: 0.7341
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5518 - accuracy: 0.7334
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5529 - accuracy: 0.7339
# Epoch 46/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5503 - accuracy: 0.7342
# Epoch 47/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5565 - accuracy: 0.7360
# Epoch 48/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5621 - accuracy: 0.7308
# Epoch 49/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5599 - accuracy: 0.7350
# Epoch 50/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5605 - accuracy: 0.7294
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5631 - accuracy: 0.7340
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5585 - accuracy: 0.7347
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5613 - accuracy: 0.7348
# Epoch 54/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5643 - accuracy: 0.7357
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5675 - accuracy: 0.7358
# Epoch 56/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5634 - accuracy: 0.7369
# Epoch 57/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5641 - accuracy: 0.7357
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5661 - accuracy: 0.7331
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5659 - accuracy: 0.7283
# Epoch 60/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5760 - accuracy: 0.7287
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5676 - accuracy: 0.7341
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5704 - accuracy: 0.7355
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5690 - accuracy: 0.7358
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5647 - accuracy: 0.7345
# Epoch 65/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5682 - accuracy: 0.7332
# Epoch 66/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5555 - accuracy: 0.7361
# Epoch 67/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5542 - accuracy: 0.7357
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5604 - accuracy: 0.7334
# Epoch 69/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5639 - accuracy: 0.7341
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5635 - accuracy: 0.7364
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5621 - accuracy: 0.7352
# Epoch 72/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5640 - accuracy: 0.7358
# Epoch 73/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5559 - accuracy: 0.7360
# Epoch 74/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5540 - accuracy: 0.7360
# Epoch 75/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5624 - accuracy: 0.7371
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5631 - accuracy: 0.7358
# Epoch 77/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5644 - accuracy: 0.7360
# Epoch 78/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5549 - accuracy: 0.7343
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5552 - accuracy: 0.7338
# Epoch 80/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5551 - accuracy: 0.7366
# Epoch 81/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5515 - accuracy: 0.7372
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5515 - accuracy: 0.7364
# Epoch 83/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5514 - accuracy: 0.7370
# Epoch 84/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5542 - accuracy: 0.7367
# Epoch 85/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5575 - accuracy: 0.7369
# Epoch 86/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5532 - accuracy: 0.7366
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5501 - accuracy: 0.7377
# Epoch 88/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5521 - accuracy: 0.7383
# Epoch 89/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5493 - accuracy: 0.7378
# Epoch 90/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5545 - accuracy: 0.7363
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5550 - accuracy: 0.7367
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5580 - accuracy: 0.7376
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5559 - accuracy: 0.7380
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5531 - accuracy: 0.7358
# Epoch 95/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5580 - accuracy: 0.7378
# Epoch 96/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5553 - accuracy: 0.7345
# Epoch 97/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5509 - accuracy: 0.7374
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5480 - accuracy: 0.7382
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5536 - accuracy: 0.7368
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5501 - accuracy: 0.7379

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.6050 - accuracy: 0.7272 - 778ms/epoch - 3ms/step
# Loss: 0.6049957871437073, Accuracy: 0.7272303104400635

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity_Optimization.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
